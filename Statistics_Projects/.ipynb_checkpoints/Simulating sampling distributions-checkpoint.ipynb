# %%
from scipy.stats import norm, sem
import matplotlib.pyplot as plt
import numpy as np

# %%
rv = norm.rvs(size = 10000)

print("Mean of 10,000 randomly sampled data points: ", np.mean(rv))
print("Std Dev. of the data points: ",np.std(rv))
print("Function result for standard error of the mean", sem(rv))
# Out:
# Mean of 10,000 randomly sampled data points:  -0.011102801889565144
# Std Dev. of the data points:  0.9926217152247652
# Function result for standard error of the mean 0.00992671350033168

# %%
print("95% confidence interval [",np.mean(rv)-1.96*sem(rv),",",np.mean(rv)+1.96*sem(rv),"]")
# Out:
# 95% confidence interval [ -0.03055916035021524 , 0.00835355657108495 ]

# %% [markdown]
# Therefore we cannot reject that the mean is anywhere in the confidence interval at this confidence level.

# %%
#comparison with function found in online forum https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data

# we are spot on!

import numpy as np
import scipy.stats


def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

mean_confidence_interval(rv,confidence = 0.95)
# Out:
# (-0.011102801889565144, -0.030561158236522494, 0.008355554457392203)

# %%
# Lets try with 2 groups

a = rv[:int(len(rv)/2)]
b = rv[int(len(rv)/2):]
n = len(rv)
ma, sea = np.mean(a),scipy.stats.sem(a)
mb, seb = np.mean(b),scipy.stats.sem(b)
ha = sea * 1.96
hb = seb * 1.96
print("mean of a: ", ma, "\n95% Confidence Interval [",ma-ha,",",ma+ha,"]\n")
print("mean of b: ", mb, "\n95% Confidence Interval [",mb-hb,",",mb+hb,"]")
# Out:
# mean of a:  -0.01248224047632869
# 95% Confidence Interval [ -0.04032083495313582 , 0.01535635400047844 ]
#
# mean of b:  -0.009723363302801586
# 95% Confidence Interval [ -0.03691455160738661 , 0.01746782500178344 ]

# %%
mm = [ma,mb]
mab = np.mean(mm)

# %%
hm = np.std([mm])

# %%
print("mean of ma and mb: ", mab, "\n95% Confidence Interval [",mab-hm,",",mab+hm,"]\n")
# Out:
# mean of ma and mb:  -0.01110280188956514
# 95% Confidence Interval [ -0.01248224047632869 , -0.009723363302801588 ]

# %%
def make_partition(r,c):
    if len(r)/c%1!=0.0:
        print("sorry not divisible")
        return
    else:
       
        part = {
        }
        for i in range(len(r)/c):
            part[i] = r[:]

# %%
def chunkIt(seq, num):
    if len(seq)/num%1!=0.0:
        print("sorry not divisible")
        return
    avg = len(seq) / float(num)
    out = []
    last = 0.0

    while last < len(seq):
        out.append(seq[int(last):int(last + avg)])
        last += avg

    return out

# %%
(len(rv)/1)%1==0.0
# Out:
# True

# %%
make_partition(rv,2)
# Out:
# sorry not divisible

# %%
def get_stuff(v):
    if v is None:
        return
    li = []
    for i in range(len(v)):
        li.append(np.mean(v[i]))
    m = np.mean(li)
    s = np.std(li)
    return m,s

# %%
get_stuff(chunkIt(rv,5))
# Out:
# (-0.011102801889565136, 0.010899688583286682)

# %%
len(rv) / float(3)
# Out:
# 3333.3333333333335

# %%
len(rv[:int(len(rv) / float(3))])
# Out:
# 3333

# %%
def test_a_bunch(s):
    for i in range(len(s)):
        print("Trying to comlete ",i+1,"\: ")
        print("mean, std = ",get_stuff(chunkIt(s,i+1)))
    return

# %%
test_a_bunch(rv)
# Out:
# Trying to comlete  1 \:
# mean, std =  (-0.011102801889565144, 0.0)
# Trying to comlete  2 \:
# mean, std =  (-0.01110280188956514, 0.001379438586763552)
# Trying to comlete  3 \:
# sorry not divisible
# mean, std =  None
# Trying to comlete